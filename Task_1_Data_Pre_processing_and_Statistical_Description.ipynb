# %% [markdown]
# <a href="https://colab.research.google.com/github/obraniff766/Wireless-Sensor-Network-Data-Analysis/blob/main/Task_1_Data_Pre_processing_and_Statistical_Description.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task 1: Data Pre-processing and Statistical Description
